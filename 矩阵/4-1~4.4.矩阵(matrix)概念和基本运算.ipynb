# %% [markdown]
# # 矩阵概念
# * 代数用用大写字母表示
# * 行列相等的也叫方阵

# %% [markdown]
# # 实现自己的矩阵
# * 参考
# ```python
# from LinearAlgebra.playLA.matrix import Matrix
# ```

# %% [markdown]
# # 矩阵的基本运算行政
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
